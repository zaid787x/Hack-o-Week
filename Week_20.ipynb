# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid787x/Hack-o-Week/blob/main/Week_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = {
    "distance": [50, 40, 25, 15, 8, 30, 12, 5, 45, 18],
    "status":   [0, 0, 0, 0, 1, 0, 1, 1, 0, 0]  # 1 = FAIL, 0 = SAFE
}

df = pd.DataFrame(data)

df
# Out:
#    distance  status
# 0        50       0
# 1        40       0
# 2        25       0
# 3        15       0
# 4         8       1
# 5        30       0
# 6        12       1
# 7         5       1
# 8        45       0
# 9        18       0

# %%
X = df[["distance"]]   # input
y = df["status"]       # output

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

print("Predictions:", y_pred)
print("Actual:", y_test.values)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Predictions: [1 0]
# Actual: [1 1]
# Accuracy: 0.5

# %%
value = float(input("Enter distance value: "))

prediction = model.predict([[value]])

if prediction[0] == 1:
    print("⚠ Machine Failure Predicted")
else:
    print("✅ Machine Safe")
# Out:
# Enter distance value: 40
# ✅ Machine Safe
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
