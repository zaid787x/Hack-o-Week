# %% [markdown]
# <a href="https://colab.research.google.com/github/zaid787x/Hack-o-Week/blob/main/Week_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = []
n = int(input("How many readings do you want to enter? "))

for i in range(n):
    d = int(input(f"Enter distance for reading {i+1}: "))
    data.append(d)

df = pd.DataFrame({
    "time": range(1, n+1),
    "distance": data
})

df
# Out:
# How many readings do you want to enter? 5
# Enter distance for reading 1: 50
# Enter distance for reading 2: 15
# Enter distance for reading 3: 8
# Enter distance for reading 4: 3
# Enter distance for reading 5: 5
#    time  distance
# 0     1        50
# 1     2        15
# 2     3         8
# 3     4         3
# 4     5         5

# %%
def classify(distance):
    if distance < 10:
        return "DANGER"
    elif distance < 20:
        return "WARNING"
    else:
        return "SAFE"

df["status"] = df["distance"].apply(classify)

df
# Out:
#    time  distance   status
# 0     1        50     SAFE
# 1     2        15  WARNING
# 2     3         8   DANGER
# 3     4         3   DANGER
# 4     5         5   DANGER

# %%
danger_cases = df[df["status"] == "DANGER"]

print("Danger Events:")
danger_cases
# Out:
# Danger Events:
#    time  distance  status
# 2     3         8  DANGER
# 3     4         3  DANGER
# 4     5         5  DANGER

# %%
import matplotlib.pyplot as plt

plt.plot(df["time"], df["distance"], marker='o')
plt.axhline(y=10, linestyle='--', label="Danger")
plt.axhline(y=20, linestyle='--', label="Warning")

plt.title("Warehouse Collision Detection")
plt.xlabel("Time")
plt.ylabel("Distance")
plt.legend()

plt.show()
